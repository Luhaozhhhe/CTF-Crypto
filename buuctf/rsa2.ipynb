# %%
N = 
e = 

import hashlib
flag = "flag{" + hashlib.md5(hex(d)).hexdigest() + "}"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       2 e = 
#       4 import hashlib
# ----> 5 flag = "flag{" + hashlib.md5(hex(d)).hexdigest() + "}"
#
# TypeError: Strings must be encoded before hashing

# %%
#分解N
p=9046853915223503351787031888977627106934564043204783593118678181991596316582877057556463152579621699010610569526573031954779520781448550677767565207407183
q=11273732364123571293429600400343309403733952146912318879993851141423284675797325272321856863528776914709992821287788339848962916204774010644058033316303937
from gmpy2 import *
e=(p-1)*(q-1)
N=p*q
d=invert(e,phi)
print(d)
# Out:
# 8920758995414587152829426558580025657357328745839747693739591820283538307445

# %%
import hashlib
d=8920758995414587152829426558580025657357328745839747693739591820283538307445
print(hex(d))
# Out:
# 0x13b8f87d588e2aa4a27296cf2898f56ab4c8deb5a1222ec080e23afecaf7f975

# %%
hex_d=0x13b8f87d588e2aa4a27296cf2898f56ab4c8deb5a1222ec080e23afecaf7f975


import hashlib
 
 
md = hashlib.md5()
md.update('0x13b8f87d588e2aa4a27296cf2898f56ab4c8deb5a1222ec080e23afecaf7f975L'.encode('utf-8'))
print("flag{" +md.hexdigest()+"}")
# Out:
# flag{47bf28da384590448e0b0d23909a25a4}
