# %%
{...,2767}

{...,3659}

message1=...

message2=...

# %%
import gmpy2 as gp
def egcd(a, b):
    if a == 0:
        return (b, 0, 1)
    else:
        g, y, x = egcd(b % a, a)
        return (g, x - (b // a) * y, y)

n = ...
c1 = ...
c2 = ...
e1 = 2767
e2 = 3659
s = egcd(e1, e2)
s1 = s[1]
s2 = s[2]
if s1<0:
    s1 = - s1
    c1 = gp.invert(c1, n)
elif s2<0:
    s2 = - s2
    c2 = gp.invert(c2, n)

m = pow(c1,s1,n)*pow(c2,s2,n) % n
print(hex(m)[2:])
print(bytes.fromhex(hex(m)[2:]))
# Out:
# 424a447b7233615f43306d6d6f4e5f6d6f44405f34747461636b7d
# b'BJD{r3a_C0mmoN_moD@_4ttack}'
